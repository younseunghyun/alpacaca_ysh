# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size

        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.o2o = nn.Linear(hidden_size + output_size, output_size)
        self.dropout = nn.Dropout(0.1)
        self.softmax = nn.LogSoftmax()

    def forward(self, input, hidden):
        input_combined = torch.cat((input, hidden), 1)
        hidden = self.i2h(input_combined)
        output = self.i2o(input_combined)
        output_combined = torch.cat((hidden, output), 1)
        output = self.o2o(output_combined)
        output = self.dropout(output)
        output = self.softmax(output)
        return output, hidden

    def initHidden(self):
        return Variable(torch.zeros(1, self.hidden_size))

# %%
feature_size = 500
n_letters = 4

# %%
criterion=nn.L1Loss()
learning_rate=0.0005
n_iters=100000
print_every=5000
plot_every=500

# %%
rnn = RNN(feature_size,feature_size,feature_size)

# %%
def train(input_line_tensor, target_line_tensor):
    global hidden
    hidden = rnn.initHidden()
    rnn.zero_grad()
    loss = 0
    for i in range(input_line_tensor.size()[0]):
        output, hidden = rnn(input_line_tensor[i], hidden)
        loss += criterion(output,target_line_tensor[i])
        
    loss.backward()

    for p in rnn.parameters():
        p.data.add_(-learning_rate, p.grad.data)

    return output, loss.data[0] / input_line_tensor.size()[0]

# %%
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
import time
import math

# %%
def run(inputFile):
    all_losses = list()
    total_loss = 0
    
    start = time.time()
    trainFile = open(inputFile,'r')
    cnt = 0
    for f in trainFile:
        input = f.strip().split('\t')
        try:
            i,o = toTrainVar(input)
            output, loss= train(i,o)
            total_loss += loss
        except Exception as e:
            print('error',e)

        cnt = cnt + 1
        
        if cnt == n_iters: break

        if cnt % 100 == 0:
            print(cnt)
        if cnt % plot_every == 0:
            print('%s (%d %d%%) %.4f' % (timeSince(start), cnt, cnt / n_iters * 100, loss))

        if cnt % plot_every == 0:
            all_losses.append(total_loss / plot_every)
            total_loss = 0

# %%
run('../embedding/embedded_result.txt')
# Out:
# 100
# 200
# 300
# 400
# 500
# 1m 3s (500 0%) 6.2146
# 600
# 700
# 800
# 900
# error could not convert string to float:
# 1000
# 2m 4s (1000 1%) 6.2148
# error could not convert string to float:
# error could not convert string to float:
# 1100
# error could not convert string to float:
# 1200
# error could not convert string to float:
# 1300
# error could not convert string to float:
# error could not convert string to float:
# 1400
# 1500
# 2m 48s (1500 1%) 6.2156
# 1600
# error could not convert string to float:
# 1700
# 1800
# 1900
# 2000
# 3m 37s (2000 2%) 6.2148
# 2100
# 2200
# 2300
# error could not convert string to float:
# 2400
# 2500
# 4m 30s (2500 2%) 6.2150
# 2600
# 2700
# 2800
# error could not convert string to float:
# 2900
# error could not convert string to float:
# error could not convert string to float:
# 3000
# 5m 19s (3000 3%) 6.2155
# error could not convert string to float:
# 3100
# 3200
# 3300
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 3400
# error could not convert string to float:
# error could not convert string to float:
# 3500
# 6m 7s (3500 3%) 6.2157
# 3600
# 3700
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 3800
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 3900
# 4000
# 6m 58s (4000 4%) 6.2147
# 4100
# error could not convert string to float:
# 4200
# 4300
# 4400
# 4500
# 7m 47s (4500 4%) 6.2151
# 4600
# error could not convert string to float:
# 4700
# error could not convert string to float:
# 4800
# 4900
# 5000
# 8m 27s (5000 5%) 6.2147
# 5100
# 5200
# 5300
# 5400
# 5500
# 9m 19s (5500 5%) 6.2146
# 5600
# error could not convert string to float:
# 5700
# 5800
# 5900
# 6000
# 10m 8s (6000 6%) 6.2148
# 6100
# error could not convert string to float:
# 6200
# 6300
# 6400
# 6500
# 10m 58s (6500 6%) 6.2148
# 6600
# error could not convert string to float:
# 6700
# error could not convert string to float:
# 6800
# error could not convert string to float:
# 6900
# 7000
# 11m 50s (7000 7%) 6.2149
# 7100
# 7200
# error could not convert string to float:
# 7300
# 7400
# 7500
# 12m 36s (7500 7%) 6.2154
# 7600
# 7700
# 7800
# 7900
# 8000
# 13m 24s (8000 8%) 6.2149
# 8100
# 8200
# 8300
# 8400
# 8500
# 14m 15s (8500 8%) 6.2151
# 8600
# 8700
# 8800
# 8900
# 9000
# 15m 13s (9000 9%) 6.2149
# 9100
# error could not convert string to float:
# 9200
# 9300
# error could not convert string to float:
# 9400
# 9500
# 16m 6s (9500 9%) 6.2152
# 9600
# error could not convert string to float:
# 9700
# 9800
# error could not convert string to float:
# 9900
# 10000
# 17m 1s (10000 10%) 6.2150
# 10100
# 10200
# error could not convert string to float:
# 10300
# 10400
# 10500
# 17m 56s (10500 10%) 6.2151
# 10600
# 10700
# 10800
# 10900
# error could not convert string to float:
# 11000
# 19m 0s (11000 11%) 6.2156
# 11100
# 11200
# 11300
# 11400
# 11500
# 19m 56s (11500 11%) 6.2151
# 11600
# 11700
# 11800
# 11900
# 12000
# 20m 48s (12000 12%) 6.2150
# 12100
# 12200
# 12300
# 12400
# 12500
# 21m 47s (12500 12%) 6.2150
# 12600
# 12700
# error could not convert string to float:
# 12800
# 12900
# 13000
# 22m 23s (13000 13%) 6.2148
# 13100
# 13200
# error could not convert string to float:
# 13300
# 13400
# 13500
# 23m 4s (13500 13%) 6.2158
# 13600
# 13700
# 13800
# error could not convert string to float:
# 13900
# 14000
# 24m 1s (14000 14%) 6.2149
# 14100
# 14200
# 14300
# 14400
# 14500
# 24m 57s (14500 14%) 6.2149
# 14600
# error could not convert string to float:
# error could not convert string to float:
# 14700
# 14800
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 14900
# 15000
# 25m 59s (15000 15%) 6.2151
# 15100
# 15200
# 15300
# 15400
# 15500
# 27m 0s (15500 15%) 6.2158
# 15600
# error could not convert string to float:
# error could not convert string to float:
# 15700
# 15800
# 15900
# 16000
# 28m 0s (16000 16%) 6.2151
# 16100
# 16200
# 16300
# error could not convert string to float:
# 16400
# 16500
# 28m 54s (16500 16%) 6.2145
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 16600
# 16700
# 16800
# error could not convert string to float:
# 16900
# 17000
# 29m 58s (17000 17%) 6.2152
# 17100
# error could not convert string to float:
# 17200
# error could not convert string to float:
# 17300
# 17400
# error could not convert string to float:
# 17500
# 30m 52s (17500 17%) 6.2151
# 17600
# 17700
# 17800
# 17900
# 18000
# 31m 40s (18000 18%) 6.2154
# 18100
# 18200
# 18300
# 18400
# 18500
# 32m 35s (18500 18%) 6.2149
# 18600
# 18700
# 18800
# error could not convert string to float:
# 18900
# 19000
# 33m 21s (19000 19%) 6.2150
# error could not convert string to float:
# 19100
# 19200
# 19300
# error could not convert string to float:
# 19400
# 19500
# 34m 25s (19500 19%) 6.2150
# 19600
# 19700
# error could not convert string to float:
# 19800
# 19900
# 20000
# 35m 19s (20000 20%) 6.2153
# 20100
# 20200
# 20300
# error could not convert string to float:
# 20400
# 20500
# 36m 17s (20500 20%) 6.2161
# 20600
# 20700
# 20800
# 20900
# 21000
# 37m 29s (21000 21%) 6.2150
# 21100
# 21200
# 21300
# 21400
# 21500
# 38m 19s (21500 21%) 6.2153
# 21600
# 21700
# 21800
# 21900
# 22000
# 39m 22s (22000 22%) 6.2150
# 22100
# 22200
# 22300
# error could not convert string to float:
# error could not convert string to float:
# 22400
# 22500
# 40m 30s (22500 22%) 6.2148
# 22600
# 22700
# 22800
# 22900
# 23000
# 41m 30s (23000 23%) 6.2156
# 23100
# 23200
# 23300
# 23400
# 23500
# 42m 19s (23500 23%) 6.2154
# 23600
# 23700
# 23800
# 23900
# 24000
# 43m 9s (24000 24%) 6.2146
# 24100
# 24200
# 24300
# 24400
# 24500
# 44m 7s (24500 24%) 6.2148
# error could not convert string to float:
# 24600
# 24700
# error could not convert string to float:
# 24800
# 24900
# 25000
# 45m 0s (25000 25%) 6.2149
# 25100
# 25200
# 25300
# 25400
# 25500
# 45m 50s (25500 25%) 6.2147
# 25600
# 25700
# 25800
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 25900
# 26000
# 46m 57s (26000 26%) 6.2146
# error could not convert string to float:
# 26100
# error could not convert string to float:
# 26200
# 26300
# 26400
# 26500
# 47m 42s (26500 26%) 6.2147
# 26600
# 26700
# 26800
# 26900
# error could not convert string to float:
# 27000
# 48m 45s (27000 27%) 6.2150
# error could not convert string to float:
# 27100
# 27200
# 27300
# 27400
# 27500
# 49m 39s (27500 27%) 6.2147
# 27600
# 27700
# error could not convert string to float:
# 27800
# 27900
# 28000
# 50m 52s (28000 28%) 6.2150
# 28100
# 28200
# 28300
# 28400
# 28500
# 51m 52s (28500 28%) 6.2150
# 28600
# 28700
# 28800
# 28900
# 29000
# 52m 56s (29000 28%) 6.2151
# 29100
# 29200
# 29300
# 29400
# 29500
# 54m 1s (29500 29%) 6.2151
# 29600
# 29700
# 29800
# 29900
# 30000
# 55m 12s (30000 30%) 6.2148
# 30100
# 30200
# 30300
# 30400
# 30500
# 56m 18s (30500 30%) 6.2153
# 30600
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 30700
# 30800
# error could not convert string to float:
# 30900
# 31000
# 57m 10s (31000 31%) 6.2154
# 31100
# 31200
# 31300
# 31400
# error could not convert string to float:
# 31500
# 58m 13s (31500 31%) 6.2151
# 31600
# 31700
# error could not convert string to float:
# error could not convert string to float:
# 31800
# 31900
# 32000
# 59m 6s (32000 32%) 6.2151
# error could not convert string to float:
# 32100
# 32200
# 32300
# 32400
# 32500
# 60m 9s (32500 32%) 6.2151
# 32600
# 32700
# 32800
# 32900
# 33000
# 60m 58s (33000 33%) 6.2146
# error could not convert string to float:
# 33100
# 33200
# 33300
# 33400
# 33500
# 62m 2s (33500 33%) 6.2151
# 33600
# error could not convert string to float:
# error could not convert string to float:
# 33700
# 33800
# 33900
# 34000
# 63m 13s (34000 34%) 6.2150
# 34100
# 34200
# error could not convert string to float:
# 34300
# 34400
# 34500
# 64m 24s (34500 34%) 6.2161
# 34600
# error could not convert string to float:
# 34700
# 34800
# 34900
# error could not convert string to float:
# 35000
# 65m 26s (35000 35%) 6.2152
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 35100
# 35200
# 35300
# 35400
# error could not convert string to float:
# 35500
# 66m 31s (35500 35%) 6.2152
# 35600
# 35700
# 35800
# error could not convert string to float:
# 35900
# 36000
# 67m 31s (36000 36%) 6.2151
# 36100
# 36200
# 36300
# 36400
# error could not convert string to float:
# 36500
# 68m 23s (36500 36%) 6.2151
# 36600
# 36700
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 36800
# 36900
# 37000
# 69m 22s (37000 37%) 6.2147
# 37100
# error could not convert string to float:
# 37200
# 37300
# 37400
# 37500
# 70m 20s (37500 37%) 6.2148
# 37600
# 37700
# 37800
# 37900
# error could not convert string to float:
# 38000
# 71m 26s (38000 38%) 6.2149
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 38100
# 38200
# 38300
# 38400
# 38500
# 72m 26s (38500 38%) 6.2154
# 38600
# 38700
# 38800
# error could not convert string to float:
# 38900
# 39000
# 73m 26s (39000 39%) 6.2150
# 39100
# 39200
# 39300
# error could not convert string to float:
# 39400
# 39500
# 74m 29s (39500 39%) 6.2150
# 39600
# 39700
# error could not convert string to float:
# 39800
# 39900
# error could not convert string to float:
# 40000
# 75m 25s (40000 40%) 6.2152
# 40100
# 40200
# 40300
# 40400
# 40500
# 76m 17s (40500 40%) 6.2152
# 40600
# 40700
# error could not convert string to float:
# 40800
# error could not convert string to float:
# 40900
# 41000
# 77m 38s (41000 41%) 6.2149
# 41100
# 41200
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 41300
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 41400
# 41500
# 78m 34s (41500 41%) 6.2146
# 41600
# 41700
# 41800
# error could not convert string to float:
# 41900
# 42000
# 79m 42s (42000 42%) 6.2147
# 42100
# error could not convert string to float:
# 42200
# 42300
# 42400
# error could not convert string to float:
# 42500
# 80m 49s (42500 42%) 6.2156
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 42600
# error could not convert string to float:
# 42700
# 42800
# 42900
# 43000
# 81m 36s (43000 43%) 6.2153
# 43100
# 43200
# 43300
# 43400
# 43500
# 82m 27s (43500 43%) 6.2151
# 43600
# 43700
# 43800
# error could not convert string to float:
# error could not convert string to float:
# 43900
# 44000
# 83m 18s (44000 44%) 6.2145
# 44100
# 44200
# 44300
# 44400
# 44500
# 84m 8s (44500 44%) 6.2148
# error could not convert string to float:
# 44600
# 44700
# 44800
# 44900
# 45000
# 85m 11s (45000 45%) 6.2146
# 45100
# error could not convert string to float:
# 45200
# 45300
# 45400
# 45500
# 86m 12s (45500 45%) 6.2153
# 45600
# 45700
# 45800
# 45900
# 46000
# 87m 0s (46000 46%) 6.2148
# 46100
# error could not convert string to float:
# 46200
# 46300
# 46400
# error could not convert string to float:
# 46500
# 87m 42s (46500 46%) 6.2155
# 46600
# 46700
# 46800
# 46900
# 47000
# 88m 34s (47000 47%) 6.2147
# 47100
# 47200
# 47300
# 47400
# 47500
# 89m 32s (47500 47%) 6.2147
# 47600
# 47700
# error could not convert string to float:
# 47800
# 47900
# 48000
# 90m 25s (48000 48%) 6.2146
# 48100
# error could not convert string to float:
# 48200
# 48300
# 48400
# 48500
# 91m 18s (48500 48%) 6.2145
# 48600
# error could not convert string to float:
# 48700
# 48800
# 48900
# 49000
# 92m 17s (49000 49%) 6.2140
# 49100
# 49200
# 49300
# 49400
# 49500
# 92m 56s (49500 49%) 6.2150
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 49600
# 49700
# 49800
# error could not convert string to float:
# 49900
# 50000
# 93m 53s (50000 50%) 6.2148
# 50100
# error could not convert string to float:
# error could not convert string to float:
# 50200
# 50300
# 50400
# 50500
# 94m 53s (50500 50%) 6.2151
# 50600
# 50700
# 50800
# 50900
# 51000
# 95m 57s (51000 51%) 6.2150
# 51100
# error could not convert string to float:
# 51200
# error could not convert string to float:
# 51300
# 51400
# 51500
# 96m 53s (51500 51%) 6.2156
# 51600
# 51700
# 51800
# 51900
# 52000
# 97m 42s (52000 52%) 6.2153
# 52100
# 52200
# 52300
# 52400
# 52500
# 98m 29s (52500 52%) 6.2151
# 52600
# 52700
# 52800
# 52900
# 53000
# 99m 34s (53000 53%) 6.2150
# 53100
# 53200
# 53300
# 53400
# error could not convert string to float:
# 53500
# 100m 34s (53500 53%) 6.2152
# 53600
# 53700
# error could not convert string to float:
# 53800
# 53900
# 54000
# 101m 40s (54000 54%) 6.2147
# 54100
# 54200
# error could not convert string to float:
# 54300
# 54400
# 54500
# 102m 27s (54500 54%) 6.2148
# 54600
# 54700
# error could not convert string to float:
# 54800
# 54900
# error could not convert string to float:
# 55000
# 103m 10s (55000 55%) 6.2149
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 55100
# 55200
# 55300
# 55400
# 55500
# 104m 1s (55500 55%) 6.2150
# 55600
# 55700
# 55800
# 55900
# 56000
# 104m 53s (56000 56%) 6.2148
# 56100
# 56200
# 56300
# error could not convert string to float:
# 56400
# 56500
# 105m 55s (56500 56%) 6.2154
# 56600
# 56700
# 56800
# 56900
# 57000
# 106m 56s (57000 56%) 6.2148
# 57100
# 57200
# 57300
# 57400
# 57500
# 107m 54s (57500 57%) 6.2152
# 57600
# 57700
# 57800
# 57900
# 58000
# 109m 10s (58000 57%) 6.2146
# 58100
# 58200
# 58300
# 58400
# 58500
# 110m 9s (58500 58%) 6.2148
# 58600
# 58700
# error could not convert string to float:
# 58800
# error could not convert string to float:
# 58900
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 59000
# 111m 10s (59000 59%) 6.2150
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 59100
# 59200
# 59300
# 59400
# 59500
# 112m 14s (59500 59%) 6.2149
# error could not convert string to float:
# 59600
# 59700
# 59800
# 59900
# 60000
# 113m 16s (60000 60%) 6.2146
# 60100
# 60200
# 60300
# 60400
# 60500
# 114m 7s (60500 60%) 6.2151
# 60600
# 60700
# 60800
# error could not convert string to float:
# 60900
# error could not convert string to float:
# 61000
# 115m 3s (61000 61%) 6.2155
# 61100
# 61200
# 61300
# 61400
# 61500
# 116m 3s (61500 61%) 6.2149
# 61600
# 61700
# 61800
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 61900
# error could not convert string to float:
# 62000
# 116m 50s (62000 62%) 6.2144
# 62100
# 62200
# 62300
# error could not convert string to float:
# 62400
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 62500
# 117m 43s (62500 62%) 6.2145
# 62600
# 62700
# 62800
# 62900
# 63000
# 118m 51s (63000 63%) 6.2151
# 63100
# error could not convert string to float:
# 63200
# 63300
# 63400
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 63500
# 119m 48s (63500 63%) 6.2151
# 63600
# 63700
# 63800
# error could not convert string to float:
# 63900
# error could not convert string to float:
# error could not convert string to float:
# 64000
# 120m 40s (64000 64%) 6.2148
# 64100
# 64200
# 64300
# 64400
# 64500
# 121m 23s (64500 64%) 6.2148
# error could not convert string to float:
# 64600
# 64700
# 64800
# 64900
# 65000
# 122m 11s (65000 65%) 6.2151
# 65100
# error could not convert string to float:
# error could not convert string to float:
# 65200
# 65300
# 65400
# error could not convert string to float:
# 65500
# 123m 8s (65500 65%) 6.2152
# error could not convert string to float:
# 65600
# 65700
# 65800
# 65900
# 66000
# 124m 0s (66000 66%) 6.2148
# 66100
# 66200
# error could not convert string to float:
# error could not convert string to float:
# 66300
# 66400
# 66500
# 124m 54s (66500 66%) 6.2152
# 66600
# 66700
# 66800
# error could not convert string to float:
# 66900
# 67000
# 125m 43s (67000 67%) 6.2147
# 67100
# 67200
# 67300
# 67400
# 67500
# 126m 49s (67500 67%) 6.2147
# 67600
# 67700
# 67800
# 67900
# 68000
# 127m 49s (68000 68%) 6.2151
# error could not convert string to float:
# error could not convert string to float:
# 68100
# 68200
# 68300
# 68400
# 68500
# 128m 56s (68500 68%) 6.2151
# 68600
# 68700
# 68800
# 68900
# error could not convert string to float:
# 69000
# 129m 57s (69000 69%) 6.2150
# 69100
# 69200
# 69300
# 69400
# 69500
# 131m 3s (69500 69%) 6.2146
# 69600
# 69700
# 69800
# 69900
# 70000
# 131m 52s (70000 70%) 6.2151
# 70100
# 70200
# 70300
# 70400
# 70500
# 132m 52s (70500 70%) 6.2147
# error could not convert string to float:
# error could not convert string to float:
# 70600
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# error could not convert string to float:
# 70700
# 70800
# 70900
# 71000
# 133m 54s (71000 71%) 6.2151
# error could not convert string to float:
# 71100
# 71200
# 71300
# 71400
# 71500
# 134m 42s (71500 71%) 6.2148
# 71600
# 71700
# error could not convert string to float:
# error could not convert string to float:
# 71800
# 71900
# 72000
# 135m 36s (72000 72%) 6.2150
# 72100
# 72200
# 72300
# 72400
# 72500
# 136m 33s (72500 72%) 6.2147
# 72600
# error could not convert string to float:
# 72700
# 72800
# 72900
# 73000
# 137m 16s (73000 73%) 6.2148
# 73100
# 73200
# 73300
# 73400
# 73500
# 138m 14s (73500 73%) 6.2148
# error could not convert string to float:
# error could not convert string to float:
# 73600
# error could not convert string to float:
# 73700
# 73800
# 73900
# error could not convert string to float:
# error could not convert string to float:
# 74000
# 139m 4s (74000 74%) 6.2157
# 74100
# 74200
# 74300
# 74400
# 74500
# 139m 54s (74500 74%) 6.2151
# 74600
# error could not convert string to float:
# 74700
# 74800
# 74900
# error could not convert string to float:
# 75000
# 140m 45s (75000 75%) 6.2149
# 75100
# error could not convert string to float:
# 75200
# 75300
# error could not convert string to float:
# 75400
# 75500
# 141m 33s (75500 75%) 6.2144
# 75600
# 75700
# 75800
# 75900
# 76000
# 142m 22s (76000 76%) 6.2150
# 76100
# error could not convert string to float:
# 76200
# 76300
# 76400
# 76500
# 143m 11s (76500 76%) 6.2152
# 76600
# 76700

# %%
def toTrainVar(input):
    tensor = torch.zeros(len(input),1 , feature_size)
    for word_idx in range(0,len(input)):
        fs = input[word_idx].split(',')
        for f_i in range(0,len(fs)):
            tensor[word_idx][0][f_i] = float(fs[f_i])
    tg = []
    for word_idx in range(0,len(input)):
        fs = input[word_idx].split(',')
        t = [float(fs[f_i]) for f_i in range(0,len(fs))]
        tg.append(t)
    tg.append([0.0 for i in range(0,feature_size)])
    targetTensor = torch.FloatTensor(tg)
    input_line_tensor = Variable(tensor)
    target_line_tensor = Variable(targetTensor)
    return input_line_tensor, target_line_tensor

# %%
train(input_line_tensor, target_line_tensor)[1]
# Out:
# 6.214851379394531

# %%
input_line_tensor = Variable(self.inputTensor(line))
target_line_tensor = Variable(self.targetTensor(line))
